# %%
import pandas as pd

# %%
orders_before_dec = pd.read_csv("C:\\Users\\bhura\\Downloads\\orders_before_dec.csv", sep ="|")
orders_before_dec
# Out:
#               date  userID  itemID  order
# 0       2020-06-01   38769    3477      1
# 1       2020-06-01   42535   30474      1
# 2       2020-06-01   42535   15833      1
# 3       2020-06-01   42535   20131      1
# 4       2020-06-01   42535    4325      1
# ...            ...     ...     ...    ...
# 767126  2020-11-30   22541     746      1
# 767127  2020-11-30   36315   22834     20
# 767128  2020-11-30    7736   18630      3
# 767129  2020-11-30    7736   29657      8
# 767130  2020-11-30   10215   29037      1
#
# [767131 rows x 4 columns]

# %%
orders_before_dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767131 entries, 0 to 767130
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    767131 non-null  object
#  1   userID  767131 non-null  int64
#  2   itemID  767131 non-null  int64
#  3   order   767131 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 23.4+ MB

# %%
orders_before_dec.describe()
# Out:
#               userID         itemID          order
# count  767131.000000  767131.000000  767131.000000
# mean    23054.439325   16521.611910       1.391146
# std     13319.108440    9445.606505       1.431194
# min         0.000000       0.000000       1.000000
# 25%     11484.500000    8362.000000       1.000000
# 50%     23060.000000   16971.000000       1.000000
# 75%     34623.000000   24576.000000       1.000000
# max     46137.000000   32775.000000     100.000000

# %%
orders_before_dec['date'].value_counts().nlargest(10)
# Out:
# 2020-11-21    6942
# 2020-06-06    6698
# 2020-11-29    6691
# 2020-11-28    6579
# 2020-11-14    6472
# 2020-06-13    6407
# 2020-11-22    6380
# 2020-11-23    6373
# 2020-11-30    6367
# 2020-11-15    6277
# Name: date, dtype: int64

# %%
orders_before_dec['userID'].value_counts().nlargest(10)
# Out:
# 3986     203
# 38862    137
# 33416    134
# 25995    133
# 23836    128
# 30664    127
# 15490    127
# 35049    117
# 7109     117
# 32172    107
# Name: userID, dtype: int64

# %%
orders_before_dec['itemID'].value_counts().nlargest(10)
# Out:
# 29657    7420
# 18630    6436
# 20131    3813
# 11251    3046
# 16059    2951
# 19043    2753
# 1970     2470
# 23050    2217
# 24763    2155
# 17419    2124
# Name: itemID, dtype: int64

# %%
orders_before_dec['order'].value_counts().nlargest(10)
# Out:
# 1     607134
# 2     102563
# 3      28863
# 4      12157
# 5       8815
# 6       2897
# 10      1589
# 8       1252
# 7        636
# 20       309
# Name: order, dtype: int64

# %%
orders_before_dec.value_counts().nlargest(5)
# Out:
# date        userID  itemID  order
# 2020-07-13  41677   7102    1        3
#                     24815   1        3
# 2020-11-10  19950   4456    6        2
# 2020-06-01  21480   30511   1        2
# 2020-07-12  20388   19909   1        2
# dtype: int64

# %%
orders_before_dec_sorted = orders_before_dec.sort_values(["userID", "date"], ascending=True)
orders_before_dec_sorted
# Out:
#               date  userID  itemID  order
# 22146   2020-06-05       0   20664      1
# 268196  2020-08-03       0   15083      1
# 268197  2020-08-03       0   12468      1
# 334333  2020-08-18       0   12505      1
# 390966  2020-09-01       0    1505      1
# ...            ...     ...     ...    ...
# 287097  2020-08-08   46137   28900      2
# 287155  2020-08-08   46137   20209      1
# 287156  2020-08-08   46137   28343      1
# 287157  2020-08-08   46137   32292      2
# 453489  2020-09-17   46137    2667      1
#
# [767131 rows x 4 columns]

# %%
orders_before_dec['date'] = pd.to_datetime(orders_before_dec['date'], errors='coerce')
orders_before_dec['month'] = orders_before_dec.date.dt.month
orders_before_dec['day'] = orders_before_dec.date.dt.day
orders_before_dec['week'] = orders_before_dec.date.dt.isocalendar().week
orders_before_dec['week'] = orders_before_dec['week']-22
orders_before_dec['week_no'] = orders_before_dec['week']%4

# %%
# Get the maximum purchase date of each customer and create a dataframe with it together with the customer's id.
ctm_max_purchase = orders_before_dec.groupby('userID').date.max().reset_index()
ctm_max_purchase.columns = ['userID','MaxPurchaseDate']

# %%
# Find the recency of each customer in days
ctm_max_purchase['Recency'] = (ctm_max_purchase['MaxPurchaseDate'].max() - ctm_max_purchase['MaxPurchaseDate']).dt.days

# %%
# Merge the dataframes ctm_dt and ctm_max_purchase[['CustomerID', 'Recency']] on the CustomerID column.
orders_before_dec = pd.merge(orders_before_dec, ctm_max_purchase[['userID', 'Recency']], on='userID')

# %%
orders_before_dec
# Out:
#              date  userID  itemID  order  month  day  week  week_no  Recency
# 0      2020-06-01   38769    3477      1      6    1     1        1        0
# 1      2020-06-01   38769   31354      2      6    1     1        1        0
# 2      2020-06-01   38769    7449      1      6    1     1        1        0
# 3      2020-06-01   38769   16629      1      6    1     1        1        0
# 4      2020-06-01   38769   10507      1      6    1     1        1        0
# ...           ...     ...     ...    ...    ...  ...   ...      ...      ...
# 767126 2020-11-30   26212    8274      1     11   30    27        3        0
# 767127 2020-11-30   25113    8683      1     11   30    27        3        0
# 767128 2020-11-30   25113    5768      1     11   30    27        3        0
# 767129 2020-11-30   25113   26354      2     11   30    27        3        0
# 767130 2020-11-30    6918   27223      3     11   30    27        3        0
#
# [767131 rows x 9 columns]

# %%
prof = ProfileReport(orders_before_dec)
prof
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-02 07:43:26.748934&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
orders_before_dec = pd.read_csv("C:\\Users\\bhura\\Downloads\\orders_before_dec.csv", sep ="|")
orders_before_dec
# Out:
#               date  userID  itemID  order
# 0       2020-06-01   38769    3477      1
# 1       2020-06-01   42535   30474      1
# 2       2020-06-01   42535   15833      1
# 3       2020-06-01   42535   20131      1
# 4       2020-06-01   42535    4325      1
# ...            ...     ...     ...    ...
# 767126  2020-11-30   22541     746      1
# 767127  2020-11-30   36315   22834     20
# 767128  2020-11-30    7736   18630      3
# 767129  2020-11-30    7736   29657      8
# 767130  2020-11-30   10215   29037      1
#
# [767131 rows x 4 columns]

# %%
order = orders_before_dec.groupby(["userID"]).count().sort_values(["order"], ascending=False).rename(columns={"order" : "Frequency_order"}).reset_index()
order
# Out:
#        userID  date  itemID  Frequency_order
# 0        3986   203     203              203
# 1       38862   137     137              137
# 2       33416   134     134              134
# 3       25995   133     133              133
# 4       23836   128     128              128
# ...       ...   ...     ...              ...
# 45760   12408     1       1                1
# 45761   37835     1       1                1
# 45762   28518     1       1                1
# 45763    4682     1       1                1
# 45764    6574     1       1                1
#
# [45765 rows x 4 columns]

# %%
#Get the frequency of number of items by user
frequency = orders_before_dec.groupby(["userID"]).count().sort_values(["itemID"], ascending=False).rename(columns={"itemID" : "Frequency_items"}).reset_index()
frequency = frequency[['userID', 'Frequency_items', 'order']]
frequency
# print(frequency.Frequency_items.value_counts()[1])
# Out:
#        userID  Frequency_items  order
# 0        3986              203    203
# 1       38862              137    137
# 2       33416              134    134
# 3       25995              133    133
# 4       23836              128    128
# ...       ...              ...    ...
# 45760   12408                1      1
# 45761   37835                1      1
# 45762   28518                1      1
# 45763    4682                1      1
# 45764    6574                1      1
#
# [45765 rows x 3 columns]

# %%
# Convert Date from object to datetime format
orders_before_dec['date'] = pd.to_datetime(orders_before_dec['date'])
orders_before_dec
# Out:
#              date  userID  itemID  order
# 0      2020-06-01   38769    3477      1
# 1      2020-06-01   42535   30474      1
# 2      2020-06-01   42535   15833      1
# 3      2020-06-01   42535   20131      1
# 4      2020-06-01   42535    4325      1
# ...           ...     ...     ...    ...
# 767126 2020-11-30   22541     746      1
# 767127 2020-11-30   36315   22834     20
# 767128 2020-11-30    7736   18630      3
# 767129 2020-11-30    7736   29657      8
# 767130 2020-11-30   10215   29037      1
#
# [767131 rows x 4 columns]

# %%
from datetime import timedelta
snapshot_date = orders_before_dec['date'].max() + timedelta(days=1)
print(snapshot_date)
# Out:
# 2020-12-01 00:00:00

# %%
orders_before_dec = orders_before_dec.groupby(['userID']).agg({
        'date': lambda x: (snapshot_date - x.max()).days})

# %%
orders_before_dec.rename(columns={'date': 'recency'}, inplace=True)

# %%
result = pd.merge(orders_before_dec, frequency, on='userID')
# sorted_result = result.sort_values(by=['recency'], ascending=True)
# sorted_result = result.sort_values(by=['Frequency_items'], ascending=False)
# sorted_result
# Out:
#        userID  recency  Frequency_items
# 3965     3986        7              203
# 38550   38862       21              137
# 33161   33416       11              134
# 25795   25995        4              133
# 23656   23836       10              128
# ...       ...      ...              ...
# 12305   12408      169                1
# 37531   37835      118                1
# 28304   28518      115                1
# 4652     4682      141                1
# 6526     6574       34                1
#
# [45765 rows x 3 columns]
